# %% [markdown]
# <a href="https://play-iowa.neurodesk.org/hub/user-redirect/lab/tree/example-notebooks/books/functional_imaging/fmriprep_example.ipynb" target="_parent"><img src="https://img.shields.io/badge/launch-binder-579aca.svg?logo=data:image/png;base64,..." alt="Open In Binder"/>  </a>
# <a href="https://colab.research.google.com/github/NeuroDesk/example-notebooks/blob/main/books/functional_imaging/fmriprep_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>  </a>

# %% [markdown]
# # Fmriprep Example
#
# Author: Steffen Bollmann

# %% [markdown]
# ## Setup Neurodesk

# %%
# %%capture
import os
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  os.environ["LD_PRELOAD"] = "";
  os.environ["APPTAINER_BINDPATH"] = "/content,/tmp,/cvmfs"
  os.environ["MPLCONFIGDIR"] = "/content/matplotlib-mpldir"
  os.environ["LMOD_CMD"] = "/usr/share/lmod/lmod/libexec/lmod"

  # !curl -J -O https://raw.githubusercontent.com/NeuroDesk/neurocommand/main/googlecolab_setup.sh
  # !chmod +x googlecolab_setup.sh
  # !./googlecolab_setup.sh

  os.environ["MODULEPATH"] = ':'.join(map(str, list(map(lambda x: os.path.join(os.path.abspath('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/'), x),os.listdir('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/')))))

# %%
# Output CPU information:
# !cat /proc/cpuinfo | grep 'vendor' | uniq
# !cat /proc/cpuinfo | grep 'model name' | uniq
# Out:
# vendor_id	: AuthenticAMD
# model name	: AMD EPYC 7742 64-Core Processor

# %% [markdown]
# ## Run fMRIprep

# %%
# load fmriprep
import lmod
import os
await lmod.load('fmriprep/22.1.1')
await lmod.list()
# Out:
# ['fmriprep/22.1.1']

# %%
# Request a freesurfer license and store it in your homedirectory. This is just an exampe - please replace with your license id:
# !echo "Steffen.Bollmann@cai.uq.edu.au" > ~/.license
# !echo "21029" >> ~/.license
# !echo "*Cqyn12sqTCxo" >> ~/.license
# !echo "FSxgcvGkNR59Y" >> ~/.license

# %%
# download data
# !datalad install https://github.com/OpenNeuroDatasets/ds000102.git
# !cd ds000102 && datalad get sub-08

# %%
# !export ITK_GLOBAL_DEFAULT_NUMBER_OF_THREADS=2 && export MPLCONFIGDIR=~/matplotlib-mpldir && fmriprep ds000102/ content/ participant --fs-license-file ~/.license --output-spaces T1w MNI152NLin2009cAsym fsaverage fsnative --participant-label 08 --nprocs $ITK_GLOBAL_DEFAULT_NUMBER_OF_THREADS --mem 10000 --skip_bids_validation -v
# Out:
# You are using fMRIPrep-22.1.1, and a newer version of fMRIPrep is available: 23.1.4.
# Please check out our documentation about how and when to upgrade:
# https://fmriprep.readthedocs.io/en/latest/faq.html#upgrading
# --topup-max-vols input is no longer used and the flag will be removed in a future release.
# 231218-22:04:02,411 cli INFO:
# 	 Telemetry system to collect crashes and errors is enabled - thanks for your feedback!. Use option ``--notrack`` to opt out.
# 231218-22:04:18,834 nipype.workflow IMPORTANT:
# 	 Running fMRIPrep version 22.1.1
#
#          License NOTICE ##################################################
#          fMRIPrep 22.1.1
#          Copyright 2022 The NiPreps Developers.
#
#          This product includes software developed by
#          the NiPreps Community (https://nipreps.org/).
#
#          Portions of this software were developed at the Department of
#          Psychology at Stanford University, Stanford, CA, US.
#
#          This software redistributes the versioneer Python package, which is
#          Public domain source code.
#
#          This software is also distributed as a Docker container image.
#          The bootstraping file for the image ("Dockerfile") is licensed
#          under the MIT License.
#
#          This software may be distributed through an add-on package called
#          "Docker Wrapper" that is under the BSD 3-clause License.
#          #################################################################
# 231218-22:04:18,834 nipype.workflow WARNING:
# 	 Previous output generated by version 0+unknown found.
# 231218-22:04:19,158 nipype.workflow IMPORTANT:
# 	 Building fMRIPrep's workflow:
#            * BIDS dataset path: /home/jovyan/example-notebooks/books/functional_imaging/ds000102.
#            * Participant list: ['08'].
#            * Run identifier: 20231218-220358_43aaeda8-750d-484c-8aca-f0307a4fd3ba.
#            * Output spaces: T1w MNI152NLin2009cAsym:res-native fsaverage:den-164k fsnative.
#            * Pre-run FreeSurfer's SUBJECTS_DIR: /home/jovyan/example-notebooks/books/functional_imaging/content/sourcedata/freesurfer.
# 231218-22:04:20,489 nipype.workflow INFO:
# 	 No single-band-reference found for sub-08_task-flanker_run-1_bold.nii.gz.
# 231218-22:04:20,927 nipype.workflow INFO:
# 	 No single-band-reference found for sub-08_task-flanker_run-2_bold.nii.gz.
# 231218-22:04:25,802 nipype.workflow INFO:
# 	 fMRIPrep workflow graph with 619 nodes built successfully.
# 231218-22:04:44,447 nipype.workflow IMPORTANT:
# 	 fMRIPrep started!
# 231218-22:04:44,813 nipype.workflow INFO:
# 	 Workflow fmriprep_22_1_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 231218-22:04:45,389 nipype.workflow INFO:
# 	 Running in parallel.
# 231218-22:04:45,392 nipype.workflow WARNING:
# 	 Some nodes exceed the total amount of memory available (10.00GB).
# 231218-22:04:45,403 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 23 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:04:45,566 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.fsdir_run_20231218_220358_43aaeda8_750d_484c_8aca_f0307a4fd3ba" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/fsdir_run_20231218_220358_43aaeda8_750d_484c_8aca_f0307a4fd3ba".
# 231218-22:04:45,569 nipype.workflow INFO:
# 	 [Node] Executing "fsdir_run_20231218_220358_43aaeda8_750d_484c_8aca_f0307a4fd3ba" <niworkflows.interfaces.bids.BIDSFreeSurferDir>
# 231218-22:04:45,593 nipype.workflow INFO:
# 	 [Node] Finished "fsdir_run_20231218_220358_43aaeda8_750d_484c_8aca_f0307a4fd3ba", elapsed time 0.000803s.
# 231218-22:04:45,597 nipype.workflow INFO:
# 	 [Job 0] Completed (fmriprep_22_1_wf.fsdir_run_20231218_220358_43aaeda8_750d_484c_8aca_f0307a4fd3ba).
# 231218-22:04:45,736 nipype.workflow INFO:
# 	 [Job 1] Cached (fmriprep_22_1_wf.single_subject_08_wf.bidssrc).
# 231218-22:04:45,738 nipype.workflow INFO:
# 	 [Job 2] Cached (fmriprep_22_1_wf.single_subject_08_wf.about).
# 231218-22:04:47,404 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 23 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:04:47,532 nipype.workflow INFO:
# 	 [Job 3] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.res_tmpl).
# 231218-22:04:47,534 nipype.workflow INFO:
# 	 [Job 4] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.full_wm).
# 231218-22:04:49,406 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 21 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:04:49,539 nipype.workflow INFO:
# 	 [Job 5] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.lap_tmpl).
# 231218-22:04:49,541 nipype.workflow INFO:
# 	 [Job 6] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_source).
# 231218-22:04:51,408 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:04:51,556 nipype.workflow INFO:
# 	 [Job 7] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.raw_sources).
# 231218-22:04:51,559 nipype.workflow INFO:
# 	 [Job 8] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.val_bold).
# 231218-22:04:53,558 nipype.workflow INFO:
# 	 [Job 9] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.get_dummy).
# 231218-22:04:53,560 nipype.workflow INFO:
# 	 [Job 10] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_source).
# 231218-22:04:55,559 nipype.workflow INFO:
# 	 [Job 11] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.raw_sources).
# 231218-22:04:55,562 nipype.workflow INFO:
# 	 [Job 12] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.val_bold).
# 231218-22:04:57,552 nipype.workflow INFO:
# 	 [Job 13] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.get_dummy).
# 231218-22:04:57,553 nipype.workflow INFO:
# 	 [Job 14] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_norm_wf.split_desc).
# 231218-22:04:59,415 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 21 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:04:59,543 nipype.workflow INFO:
# 	 [Job 15] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_reports_wf.tf_select).
# 231218-22:04:59,544 nipype.workflow INFO:
# 	 [Job 16] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_std_trans_wf.split_target).
# 231218-22:05:01,417 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 19 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:01,546 nipype.workflow INFO:
# 	 [Job 17] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_std_trans_wf.select_tpl).
# 231218-22:05:01,547 nipype.workflow INFO:
# 	 [Job 18] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.spacesource).
# 231218-22:05:03,419 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 17 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:03,551 nipype.workflow INFO:
# 	 [Job 19] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_std_trans_wf.split_target).
# 231218-22:05:03,553 nipype.workflow INFO:
# 	 [Job 20] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_std_trans_wf.select_tpl).
# 231218-22:05:05,421 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 15 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:05,547 nipype.workflow INFO:
# 	 [Job 21] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.spacesource).
# 231218-22:05:05,549 nipype.workflow INFO:
# 	 [Job 22] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.spacesource).
# 231218-22:05:07,551 nipype.workflow INFO:
# 	 [Job 23] Cached (fmriprep_22_1_wf.single_subject_08_wf.bids_info).
# 231218-22:05:07,554 nipype.workflow INFO:
# 	 [Job 24] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_template_wf.t1w_ref_dimensions).
# 231218-22:05:09,425 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 18 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:09,555 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.ds_report_about" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/ds_report_about".
# 231218-22:05:09,558 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_about" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:05:09,567 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_about", elapsed time 0.007254s.
# 231218-22:05:09,569 nipype.workflow INFO:
# 	 [Job 25] Completed (fmriprep_22_1_wf.single_subject_08_wf.ds_report_about).
# 231218-22:05:09,698 nipype.workflow INFO:
# 	 [Job 26] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.mrg_tmpl).
# 231218-22:05:09,700 nipype.workflow INFO:
# 	 [Job 27] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.select_bold).
# 231218-22:05:11,427 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:11,557 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.ds_report_validation" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/ds_report_validation".
# 231218-22:05:11,560 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_validation" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:05:11,566 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_validation", elapsed time 0.005226s.
# 231218-22:05:11,568 nipype.workflow INFO:
# 	 [Job 28] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.ds_report_validation).
# 231218-22:05:11,698 nipype.workflow INFO:
# 	 [Job 29] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.calc_dummy_scans).
# 231218-22:05:11,702 nipype.workflow INFO:
# 	 [Job 30] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.gen_avg).
# 231218-22:05:13,428 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 15 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:13,559 nipype.workflow INFO:
# 	 [Job 31] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.select_bold).
# 231218-22:05:13,562 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.ds_report_validation" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/ds_report_validation".
# 231218-22:05:13,565 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_validation" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:05:13,571 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_validation", elapsed time 0.005116s.
# 231218-22:05:13,573 nipype.workflow INFO:
# 	 [Job 32] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.ds_report_validation).
# 231218-22:05:13,704 nipype.workflow INFO:
# 	 [Job 33] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.calc_dummy_scans).
# 231218-22:05:15,430 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:15,563 nipype.workflow INFO:
# 	 [Job 34] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.gen_avg).
# 231218-22:05:15,565 nipype.workflow INFO:
# 	 [Job 35] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_norm_wf.tf_select).
# 231218-22:05:17,562 nipype.workflow INFO:
# 	 [Job 36] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.gen_tplid).
# 231218-22:05:17,564 nipype.workflow INFO:
# 	 [Job 37] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.select_tpl).
# 231218-22:05:19,434 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:19,566 nipype.workflow INFO:
# 	 [Job 38] Cached (fmriprep_22_1_wf.single_subject_08_wf.summary).
# 231218-22:05:21,437 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 10 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 1/2.
#                      Currently running:
#                        * fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.fs_isrunning
# 231218-22:05:21,569 nipype.workflow INFO:
# 	 [Job 40] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_template_wf.t1w_conform).
# 231218-22:05:23,234 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.fs_isrunning" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/fs_isrunning".
# 231218-22:05:23,236 nipype.workflow INFO:
# 	 [Node] Executing "fs_isrunning" <nipype.interfaces.utility.wrappers.Function>
# 231218-22:05:23,249 nipype.workflow INFO:
# 	 [Node] Finished "fs_isrunning", elapsed time 0.00275s.
# 231218-22:05:23,437 nipype.workflow INFO:
# 	 [Job 39] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.fs_isrunning).
# 231218-22:05:23,440 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:23,579 nipype.workflow INFO:
# 	 [Job 41] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_reports_wf.t1w_conform_check).
# 231218-22:05:23,581 nipype.workflow INFO:
# 	 [Job 42] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.raw_sources).
# 231218-22:05:25,441 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:25,572 nipype.workflow INFO:
# 	 [Job 43] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_split).
# 231218-22:05:25,575 nipype.workflow INFO:
# 	 [Job 44] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.init_aff).
# 231218-22:05:27,573 nipype.workflow INFO:
# 	 [Job 45] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_hmc_wf.mcflirt).
# 231218-22:05:27,576 nipype.workflow INFO:
# 	 [Job 46] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_split).
# 231218-22:05:29,444 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:29,573 nipype.workflow INFO:
# 	 [Job 47] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.init_aff).
# 231218-22:05:29,576 nipype.workflow INFO:
# 	 [Job 48] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_hmc_wf.mcflirt).
# 231218-22:05:31,446 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:31,576 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.ds_report_summary" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/ds_report_summary".
# 231218-22:05:31,579 nipype.workflow INFO:
# 	 [Node] Executing "ds_report_summary" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:05:31,586 nipype.workflow INFO:
# 	 [Node] Finished "ds_report_summary", elapsed time 0.00535s.
# 231218-22:05:31,588 nipype.workflow INFO:
# 	 [Job 49] Completed (fmriprep_22_1_wf.single_subject_08_wf.ds_report_summary).
# 231218-22:05:31,720 nipype.workflow INFO:
# 	 [Job 50] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_template_wf.get1st).
# 231218-22:05:31,723 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_reports_wf.ds_t1w_conform_report" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_reports_wf/ds_t1w_conform_report".
# 231218-22:05:31,726 nipype.workflow INFO:
# 	 [Node] Executing "ds_t1w_conform_report" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:05:31,732 nipype.workflow INFO:
# 	 [Node] Finished "ds_t1w_conform_report", elapsed time 0.005117s.
# 231218-22:05:31,734 nipype.workflow INFO:
# 	 [Job 51] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_reports_wf.ds_t1w_conform_report).
# 231218-22:05:31,875 nipype.workflow INFO:
# 	 [Job 52] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_std_trans_wf.gen_ref).
# 231218-22:05:33,448 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:33,583 nipype.workflow INFO:
# 	 [Job 53] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.norm).
# 231218-22:05:33,599 nipype.workflow INFO:
# 	 [Job 54] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_hmc_wf.fsl2itk).
# 231218-22:05:35,450 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 11 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:35,586 nipype.workflow INFO:
# 	 [Job 55] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_hmc_wf.normalize_motion).
# 231218-22:05:35,595 nipype.workflow INFO:
# 	 [Job 56] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_confounds_wf.add_rmsd_header).
# 231218-22:05:37,588 nipype.workflow INFO:
# 	 [Job 57] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_std_trans_wf.gen_ref).
# 231218-22:05:37,592 nipype.workflow INFO:
# 	 [Job 58] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.norm).
# 231218-22:05:39,454 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:39,596 nipype.workflow INFO:
# 	 [Job 59] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_hmc_wf.fsl2itk).
# 231218-22:05:39,606 nipype.workflow INFO:
# 	 [Job 60] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_hmc_wf.normalize_motion).
# 231218-22:05:41,456 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:41,595 nipype.workflow INFO:
# 	 [Job 61] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_confounds_wf.add_rmsd_header).
# 231218-22:05:41,597 nipype.workflow INFO:
# 	 [Job 62] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_validate).
# 231218-22:05:43,458 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:43,588 nipype.workflow INFO:
# 	 [Job 63] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.map_brainmask).
# 231218-22:05:43,590 nipype.workflow INFO:
# 	 [Job 64] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_bold_trans_wf.merge_xforms).
# 231218-22:05:45,594 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.ds_bold_hmc_xfm" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/ds_bold_hmc_xfm".
# 231218-22:05:45,598 nipype.workflow INFO:
# 	 [Node] Executing "ds_bold_hmc_xfm" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:05:45,603 nipype.workflow INFO:
# 	 [Node] Finished "ds_bold_hmc_xfm", elapsed time 0.004236s.
# 231218-22:05:45,605 nipype.workflow INFO:
# 	 [Job 65] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.ds_bold_hmc_xfm).
# 231218-22:05:45,735 nipype.workflow INFO:
# 	 [Job 66] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_confounds_wf.fdisp).
# 231218-22:05:45,737 nipype.workflow INFO:
# 	 [Job 67] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_confounds_wf.add_motion_headers).
# 231218-22:05:47,462 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:47,591 nipype.workflow INFO:
# 	 [Job 68] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.map_brainmask).
# 231218-22:05:47,593 nipype.workflow INFO:
# 	 [Job 69] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_bold_trans_wf.merge_xforms).
# 231218-22:05:49,593 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.ds_bold_hmc_xfm" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/ds_bold_hmc_xfm".
# 231218-22:05:49,596 nipype.workflow INFO:
# 	 [Node] Executing "ds_bold_hmc_xfm" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:05:49,601 nipype.workflow INFO:
# 	 [Node] Finished "ds_bold_hmc_xfm", elapsed time 0.004095s.
# 231218-22:05:49,603 nipype.workflow INFO:
# 	 [Job 70] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.ds_bold_hmc_xfm).
# 231218-22:05:49,733 nipype.workflow INFO:
# 	 [Job 71] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_confounds_wf.fdisp).
# 231218-22:05:49,736 nipype.workflow INFO:
# 	 [Job 72] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_confounds_wf.add_motion_headers).
# 231218-22:05:51,466 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:51,594 nipype.workflow INFO:
# 	 [Job 73] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.truncate_images).
# 231218-22:05:51,597 nipype.workflow INFO:
# 	 [Job 74] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.recon_config).
# 231218-22:05:53,468 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:53,597 nipype.workflow INFO:
# 	 [Job 75] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.fov_check).
# 231218-22:05:53,600 nipype.workflow INFO:
# 	 [Job 76] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.check_hdr).
# 231218-22:05:55,623 nipype.workflow INFO:
# 	 [Job 77] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.bold_bold_trans_wf.bold_transform).
# 231218-22:05:55,626 nipype.workflow INFO:
# 	 [Job 78] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.check_hdr).
# 231218-22:05:57,611 nipype.workflow INFO:
# 	 [Job 79] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_bold_trans_wf.bold_transform).
# 231218-22:05:57,615 nipype.workflow INFO:
# 	 [Job 80] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.inu_n4).
# 231218-22:05:59,473 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 152 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:05:59,607 nipype.workflow INFO:
# 	 [Job 82] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.n4_correct).
# 231218-22:06:01,453 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.autorecon1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/surface_recon_wf/autorecon1".
# 231218-22:06:01,456 nipype.workflow INFO:
# 	 [Node] Executing "autorecon1" <smriprep.interfaces.freesurfer.ReconAll>
# 231218-22:06:01,457 nipype.interface INFO:
# 	 recon-all complete : Not running
# 231218-22:06:01,457 nipype.interface INFO:
# 	 recon-all complete : Not running
# 231218-22:06:01,476 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 296 jobs ready. Free memory (GB): 5.00/10.00, Free processors: 1/2.
#                      Currently running:
#                        * fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.autorecon1
# 231218-22:06:01,546 nipype.workflow INFO:
# 	 [Node] Finished "autorecon1", elapsed time 0.088632s.
# 231218-22:06:01,611 nipype.workflow INFO:
# 	 [Job 84] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.n4_correct).
# 231218-22:06:03,476 nipype.workflow INFO:
# 	 [Job 81] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.autorecon1).
# 231218-22:06:03,478 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 297 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:03,607 nipype.workflow INFO:
# 	 [Job 86] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.res_target).
# 231218-22:06:03,609 nipype.workflow INFO:
# 	 [Job 87] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.lap_target).
# 231218-22:06:05,633 nipype.workflow INFO:
# 	 [Job 88] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.fsnative2t1w_xfm).
# 231218-22:06:05,636 nipype.workflow INFO:
# 	 [Job 89] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.skullstrip_first_pass).
# 231218-22:06:07,482 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 298 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:07,633 nipype.workflow INFO:
# 	 [Job 91] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.skullstrip_first_pass).
# 231218-22:06:07,637 nipype.workflow INFO:
# 	 [Job 93] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.init_aff).
# 231218-22:06:09,484 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 297 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:09,637 nipype.workflow INFO:
# 	 [Job 94] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.mrg_target).
# 231218-22:06:09,640 nipype.workflow INFO:
# 	 [Job 95] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.t1w2fsnative_xfm).
# 231218-22:06:11,636 nipype.workflow INFO:
# 	 [Job 96] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.lta2itk_inv).
# 231218-22:06:11,639 nipype.workflow INFO:
# 	 [Job 97] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.first_dilate).
# 231218-22:06:13,640 nipype.workflow INFO:
# 	 [Job 100] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.first_dilate).
# 231218-22:06:13,646 nipype.workflow INFO:
# 	 [Job 103] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.norm).
# 231218-22:06:15,490 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 298 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:15,641 nipype.workflow INFO:
# 	 [Job 104] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.lta2itk_fwd).
# 231218-22:06:15,645 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_fsnative_t1w" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_fsnative_t1w".
# 231218-22:06:15,649 nipype.workflow INFO:
# 	 [Node] Executing "ds_fsnative_t1w" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:06:15,655 nipype.workflow INFO:
# 	 [Node] Finished "ds_fsnative_t1w", elapsed time 0.004709s.
# 231218-22:06:15,657 nipype.workflow INFO:
# 	 [Job 105] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_fsnative_t1w).
# 231218-22:06:15,810 nipype.workflow INFO:
# 	 [Job 106] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.first_mask).
# 231218-22:06:17,492 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 297 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:17,643 nipype.workflow INFO:
# 	 [Job 109] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.first_mask).
# 231218-22:06:17,649 nipype.workflow INFO:
# 	 [Job 112] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.map_brainmask).
# 231218-22:06:19,651 nipype.workflow INFO:
# 	 [Job 113] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.map_wmmask).
# 231218-22:06:19,655 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_t1w_fsnative" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_t1w_fsnative".
# 231218-22:06:19,658 nipype.workflow INFO:
# 	 [Node] Executing "ds_t1w_fsnative" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:06:19,664 nipype.workflow INFO:
# 	 [Node] Finished "ds_t1w_fsnative", elapsed time 0.003876s.
# 231218-22:06:19,666 nipype.workflow INFO:
# 	 [Job 114] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_t1w_fsnative).
# 231218-22:06:19,796 nipype.workflow INFO:
# 	 [Job 115] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.unifize).
# 231218-22:06:21,494 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 296 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:21,623 nipype.workflow INFO:
# 	 [Job 117] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.unifize).
# 231218-22:06:21,625 nipype.workflow INFO:
# 	 [Job 119] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.thr_brainmask).
# 231218-22:06:23,496 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 297 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:23,627 nipype.workflow INFO:
# 	 [Job 120] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.inu_n4_final).
# 231218-22:06:23,630 nipype.workflow INFO:
# 	 [Job 121] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.fixhdr_unifize).
# 231218-22:06:25,628 nipype.workflow INFO:
# 	 [Job 123] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.fixhdr_unifize).
# 231218-22:06:25,630 nipype.workflow INFO:
# 	 [Job 125] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.dil_brainmask).
# 231218-22:06:27,627 nipype.workflow INFO:
# 	 [Job 126] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.03_pad_mask).
# 231218-22:06:27,630 nipype.workflow INFO:
# 	 [Job 127] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.apply_mask).
# 231218-22:06:29,500 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 295 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:29,628 nipype.workflow INFO:
# 	 [Job 128] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.skullstrip_second_pass).
# 231218-22:06:29,630 nipype.workflow INFO:
# 	 [Job 130] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.skullstrip_second_pass).
# 231218-22:06:31,631 nipype.workflow INFO:
# 	 [Job 132] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.get_brainmask).
# 231218-22:06:31,634 nipype.workflow INFO:
# 	 [Job 133] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.fixhdr_skullstrip2).
# 231218-22:06:33,633 nipype.workflow INFO:
# 	 [Job 135] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.fixhdr_skullstrip2).
# 231218-22:06:33,636 nipype.workflow INFO:
# 	 [Job 137] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.01_atropos).
# 231218-22:06:35,506 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 296 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:35,636 nipype.workflow INFO:
# 	 [Job 138] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.combine_masks).
# 231218-22:06:35,639 nipype.workflow INFO:
# 	 [Job 140] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.combine_masks).
# 231218-22:06:37,638 nipype.workflow INFO:
# 	 [Job 142] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.02_pad_segm).
# 231218-22:06:37,641 nipype.workflow INFO:
# 	 [Job 143] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.match_wm).
# 231218-22:06:39,633 nipype.workflow INFO:
# 	 [Job 144] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.apply_mask).
# 231218-22:06:39,635 nipype.workflow INFO:
# 	 [Job 147] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.initial_boldref_wf.enhance_and_skullstrip_bold_wf.apply_mask).
# 231218-22:06:41,512 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 294 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:41,639 nipype.workflow INFO:
# 	 [Job 150] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.04_sel_labels).
# 231218-22:06:41,642 nipype.workflow INFO:
# 	 [Job 151] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.overlap).
# 231218-22:06:43,514 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 297 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:43,643 nipype.workflow INFO:
# 	 [Job 154] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.05_get_wm).
# 231218-22:06:43,645 nipype.workflow INFO:
# 	 [Job 155] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.06_get_gm).
# 231218-22:06:45,644 nipype.workflow INFO:
# 	 [Job 156] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.10_me_csf).
# 231218-22:06:45,647 nipype.workflow INFO:
# 	 [Job 157] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.27_depad_csf).
# 231218-22:06:47,517 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 295 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:47,646 nipype.workflow INFO:
# 	 [Job 158] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.sel_wm).
# 231218-22:06:47,648 nipype.workflow INFO:
# 	 [Job 161] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.09_relabel_wm).
# 231218-22:06:49,639 nipype.workflow INFO:
# 	 [Job 162] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.07_fill_gm).
# 231218-22:06:49,642 nipype.workflow INFO:
# 	 [Job 163] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.copy_xform_wm).
# 231218-22:06:51,672 nipype.workflow INFO:
# 	 [Job 166] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.26_depad_wm).
# 231218-22:06:51,675 nipype.workflow INFO:
# 	 [Job 167] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.08_mult_gm).
# 231218-22:06:53,524 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 294 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:53,679 nipype.workflow INFO:
# 	 [Job 168] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.apply_wm_prior).
# 231218-22:06:53,682 nipype.workflow INFO:
# 	 [Job 171] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.11_add_gm).
# 231218-22:06:55,681 nipype.workflow INFO:
# 	 [Job 172] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.inu_n4_final).
# 231218-22:06:55,683 nipype.workflow INFO:
# 	 [Job 175] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.12_relabel_gm).
# 231218-22:06:57,679 nipype.workflow INFO:
# 	 [Job 178] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.13_add_gm_wm).
# 231218-22:06:57,682 nipype.workflow INFO:
# 	 [Job 179] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.25_depad_gm).
# 231218-22:06:59,530 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 295 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:06:59,682 nipype.workflow INFO:
# 	 [Job 182] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.14_sel_labels2).
# 231218-22:06:59,685 nipype.workflow INFO:
# 	 [Job 183] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.24_depad_segm).
# 231218-22:07:01,532 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 294 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:01,685 nipype.workflow INFO:
# 	 [Job 184] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.merge_tpms).
# 231218-22:07:01,688 nipype.workflow INFO:
# 	 [Job 191] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.15_add_7).
# 231218-22:07:03,534 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 293 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:03,686 nipype.workflow INFO:
# 	 [Job 198] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.16_me_7).
# 231218-22:07:03,688 nipype.workflow INFO:
# 	 [Job 527] Cached (_threshold0).
# 231218-22:07:05,536 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 292 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:05,689 nipype.workflow INFO:
# 	 [Job 201] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.17_comp_7).
# 231218-22:07:05,691 nipype.workflow INFO:
# 	 [Job 528] Cached (_threshold1).
# 231218-22:07:07,537 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 291 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:07,691 nipype.workflow INFO:
# 	 [Job 202] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.18_md_7).
# 231218-22:07:07,693 nipype.workflow INFO:
# 	 [Job 529] Cached (_threshold2).
# 231218-22:07:09,539 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 290 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:09,691 nipype.workflow INFO:
# 	 [Job 203] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.19_fill_7).
# 231218-22:07:09,693 nipype.workflow INFO:
# 	 [Job 530] Cached (_threshold3).
# 231218-22:07:11,541 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 289 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:11,692 nipype.workflow INFO:
# 	 [Job 204] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.20_add_7_2).
# 231218-22:07:11,694 nipype.workflow INFO:
# 	 [Job 531] Cached (_threshold4).
# 231218-22:07:13,543 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 288 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:13,695 nipype.workflow INFO:
# 	 [Job 205] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.21_md_7_2).
# 231218-22:07:13,697 nipype.workflow INFO:
# 	 [Job 532] Cached (_threshold5).
# 231218-22:07:15,544 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 287 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:15,695 nipype.workflow INFO:
# 	 [Job 206] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.22_me_7_2).
# 231218-22:07:15,697 nipype.workflow INFO:
# 	 [Job 533] Cached (_threshold6).
# 231218-22:07:17,546 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 286 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:17,698 nipype.workflow INFO:
# 	 [Job 207] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.23_depad_mask).
# 231218-22:07:17,700 nipype.workflow INFO:
# 	 [Job 534] Cached (_threshold7).
# 231218-22:07:19,548 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 285 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:19,701 nipype.workflow INFO:
# 	 [Job 208] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.msk_conform).
# 231218-22:07:19,703 nipype.workflow INFO:
# 	 [Job 535] Cached (_threshold8).
# 231218-22:07:21,550 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 284 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:21,703 nipype.workflow INFO:
# 	 [Job 209] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.copy_xform).
# 231218-22:07:21,705 nipype.workflow INFO:
# 	 [Job 536] Cached (_threshold9).
# 231218-22:07:23,552 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 286 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:23,692 nipype.workflow INFO:
# 	 [Job 210] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.brain_extraction_wf.atropos_wf.apply_mask).
# 231218-22:07:23,696 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_t1w_preproc" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_t1w_preproc".
# 231218-22:07:23,699 nipype.workflow INFO:
# 	 [Node] Executing "ds_t1w_preproc" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:07:25,539 nipype.workflow INFO:
# 	 [Node] Finished "ds_t1w_preproc", elapsed time 1.838519s.
# 231218-22:07:25,541 nipype.workflow INFO:
# 	 [Job 211] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_t1w_preproc).
# 231218-22:07:25,677 nipype.workflow INFO:
# 	 [Job 212] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.gen_ref).
# 231218-22:07:25,682 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 284 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:25,813 nipype.workflow INFO:
# 	 [Job 213] Cached (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_norm_wf.trunc_mov).
# 231218-22:07:26,814 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.skull_strip_extern" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/surface_recon_wf/skull_strip_extern".
# 231218-22:07:26,816 nipype.workflow INFO:
# 	 [Node] Executing "skull_strip_extern" <niworkflows.interfaces.freesurfer.FSInjectBrainExtracted>
# 231218-22:07:27,219 nipype.workflow INFO:
# 	 [Node] Finished "skull_strip_extern", elapsed time 0.402319s.
# 231218-22:07:27,682 nipype.workflow INFO:
# 	 [Job 214] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.skull_strip_extern).
# 231218-22:07:27,685 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 283 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:27,816 nipype.workflow INFO:
# 	 [Job 537] Cached (_threshold10).
# 231218-22:07:27,816 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.autorecon_resume_wf.autorecon2_vol" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/surface_recon_wf/autorecon_resume_wf/autorecon2_vol".
# 231218-22:07:27,819 nipype.workflow INFO:
# 	 [Node] Executing "autorecon2_vol" <smriprep.interfaces.freesurfer.ReconAll>
# 231218-22:07:27,820 nipype.interface INFO:
# 	 recon-all complete : Not running
# 231218-22:07:27,821 nipype.interface INFO:
# 	 recon-all complete : Not running
# 231218-22:07:27,957 nipype.workflow INFO:
# 	 [Node] Finished "autorecon2_vol", elapsed time 0.137099s.
# 231218-22:07:29,684 nipype.workflow INFO:
# 	 [Job 215] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.surface_recon_wf.autorecon_resume_wf.autorecon2_vol).
# 231218-22:07:29,687 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 282 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:29,826 nipype.workflow INFO:
# 	 [Job 538] Cached (_threshold11).
# 231218-22:07:29,827 nipype.workflow INFO:
# 	 [Job 539] Cached (_threshold12).
# 231218-22:07:31,688 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 281 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:31,821 nipype.workflow INFO:
# 	 [Job 540] Cached (_threshold13).
# 231218-22:07:31,822 nipype.workflow INFO:
# 	 [Job 541] Cached (_threshold14).
# 231218-22:07:33,690 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 279 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:33,820 nipype.workflow INFO:
# 	 [Job 542] Cached (_threshold15).
# 231218-22:07:33,822 nipype.workflow INFO:
# 	 [Job 543] Cached (_threshold16).
# 231218-22:07:35,692 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 277 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:07:35,821 nipype.workflow INFO:
# 	 [Job 544] Cached (_threshold17).
# 231218-22:07:35,822 nipype.workflow INFO:
# ...
# 	 [Node] Finished "_ds_surfs1", elapsed time 0.00306s.
# 231218-22:29:24,2 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_surfs2" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_surfs/mapflow/_ds_surfs2".
# 231218-22:29:24,5 nipype.workflow INFO:
# 	 [Node] Executing "_ds_surfs2" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:29:24,9 nipype.workflow INFO:
# 	 [Node] Finished "_ds_surfs2", elapsed time 0.003063s.
# 231218-22:29:24,13 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_surfs3" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_surfs/mapflow/_ds_surfs3".
# 231218-22:29:24,16 nipype.workflow INFO:
# 	 [Node] Executing "_ds_surfs3" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:29:24,20 nipype.workflow INFO:
# 	 [Node] Finished "_ds_surfs3", elapsed time 0.00301s.
# 231218-22:29:24,23 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_surfs4" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_surfs/mapflow/_ds_surfs4".
# 231218-22:29:24,26 nipype.workflow INFO:
# 	 [Node] Executing "_ds_surfs4" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:29:24,30 nipype.workflow INFO:
# 	 [Node] Finished "_ds_surfs4", elapsed time 0.002989s.
# 231218-22:29:24,34 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_surfs5" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_surfs/mapflow/_ds_surfs5".
# 231218-22:29:24,37 nipype.workflow INFO:
# 	 [Node] Executing "_ds_surfs5" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:29:24,41 nipype.workflow INFO:
# 	 [Node] Finished "_ds_surfs5", elapsed time 0.002755s.
# 231218-22:29:24,44 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_surfs6" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_surfs/mapflow/_ds_surfs6".
# 231218-22:29:24,47 nipype.workflow INFO:
# 	 [Node] Executing "_ds_surfs6" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:29:24,50 nipype.workflow INFO:
# 	 [Node] Finished "_ds_surfs6", elapsed time 0.002678s.
# 231218-22:29:24,54 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_surfs7" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/anat_preproc_wf/anat_derivatives_wf/ds_surfs/mapflow/_ds_surfs7".
# 231218-22:29:24,57 nipype.workflow INFO:
# 	 [Node] Executing "_ds_surfs7" <smriprep.interfaces.DerivativesDataSink>
# 231218-22:29:24,61 nipype.workflow INFO:
# 	 [Node] Finished "_ds_surfs7", elapsed time 0.003156s.
# 231218-22:29:24,66 nipype.workflow INFO:
# 	 [Job 296] Completed (fmriprep_22_1_wf.single_subject_08_wf.anat_preproc_wf.anat_derivatives_wf.ds_surfs).
# 231218-22:29:24,206 nipype.workflow INFO:
# 	 [Job 431] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_surf_wf.update_metadata).
# 231218-22:29:24,207 nipype.workflow INFO:
# 	 [Job 1504] Cached (_name_surfs1).
# 231218-22:29:25,826 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:25,966 nipype.workflow INFO:
# 	 [Job 448] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.bold_surf_wf.outputnode).
# 231218-22:29:25,969 nipype.workflow INFO:
# 	 [Job 476] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.name_surfs).
# 231218-22:29:27,828 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:27,969 nipype.workflow INFO:
# 	 [Job 464] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.select_fs_surf).
# 231218-22:29:27,971 nipype.workflow INFO:
# 	 [Job 465] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.select_fs_surf).
# 231218-22:29:29,830 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:29,988 nipype.workflow INFO:
# 	 [Job 1505] Cached (_name_surfs0).
# 231218-22:29:29,988 nipype.workflow INFO:
# 	 [Job 1506] Cached (_name_surfs1).
# 231218-22:29:31,832 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 7 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:31,973 nipype.workflow INFO:
# 	 [Job 477] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.name_surfs).
# 231218-22:29:31,975 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:31,978 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:31,984 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.004942s.
# 231218-22:29:31,986 nipype.workflow INFO:
# 	 [Job 1507] Completed (_ds_bold_surfs0).
# 231218-22:29:32,126 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:32,130 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:32,135 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004695s.
# 231218-22:29:32,137 nipype.workflow INFO:
# 	 [Job 1508] Completed (_ds_bold_surfs1).
# 231218-22:29:32,277 nipype.workflow INFO:
# 	 [Job 1509] Cached (_name_surfs0).
# 231218-22:29:33,834 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:33,985 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:33,988 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:33,994 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.004642s.
# 231218-22:29:33,998 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:34,1 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:34,6 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004236s.
# 231218-22:29:34,10 nipype.workflow INFO:
# 	 [Job 500] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.ds_bold_surfs).
# 231218-22:29:34,166 nipype.workflow INFO:
# 	 [Job 1510] Cached (_name_surfs1).
# 231218-22:29:34,167 nipype.workflow INFO:
# 	 [Job 1511] Cached (_name_surfs0).
# 231218-22:29:35,835 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:35,982 nipype.workflow INFO:
# 	 [Job 482] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.name_surfs).
# 231218-22:29:35,983 nipype.workflow INFO:
# 	 [Job 1512] Cached (_name_surfs1).
# 231218-22:29:37,978 nipype.workflow INFO:
# 	 [Job 483] Cached (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.name_surfs).
# 231218-22:29:37,995 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:37,998 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:38,4 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.004986s.
# 231218-22:29:38,6 nipype.workflow INFO:
# 	 [Job 1513] Completed (_ds_bold_surfs0).
# 231218-22:29:38,148 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:38,151 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:38,157 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004797s.
# 231218-22:29:38,162 nipype.workflow INFO:
# 	 [Job 1514] Completed (_ds_bold_surfs1).
# 231218-22:29:39,840 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:39,999 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:40,2 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:40,8 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.004847s.
# 231218-22:29:40,11 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_1_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:40,14 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:40,19 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.00414s.
# 231218-22:29:40,23 nipype.workflow INFO:
# 	 [Job 501] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_1_wf.func_derivatives_wf.ds_bold_surfs).
# 231218-22:29:40,190 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:40,193 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:40,199 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.004658s.
# 231218-22:29:40,200 nipype.workflow INFO:
# 	 [Job 1515] Completed (_ds_bold_surfs0).
# 231218-22:29:40,340 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:40,343 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:40,349 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004548s.
# 231218-22:29:40,351 nipype.workflow INFO:
# 	 [Job 1516] Completed (_ds_bold_surfs1).
# 231218-22:29:41,840 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:41,995 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:41,998 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:42,5 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.005331s.
# 231218-22:29:42,8 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsaverage/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:42,11 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:42,17 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004166s.
# 231218-22:29:42,20 nipype.workflow INFO:
# 	 [Job 503] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.ds_bold_surfs).
# 231218-22:29:42,155 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:42,158 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:42,164 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.004629s.
# 231218-22:29:42,166 nipype.workflow INFO:
# 	 [Job 1517] Completed (_ds_bold_surfs0).
# 231218-22:29:42,306 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:42,309 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:42,315 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004528s.
# 231218-22:29:42,317 nipype.workflow INFO:
# 	 [Job 1518] Completed (_ds_bold_surfs1).
# 231218-22:29:43,842 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 2/2.
# 231218-22:29:43,994 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 231218-22:29:43,997 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:44,4 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.00493s.
# 231218-22:29:44,7 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/work/fmriprep_22_1_wf/single_subject_08_wf/func_preproc_task_flanker_run_2_wf/func_derivatives_wf/_key_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 231218-22:29:44,10 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 231218-22:29:44,16 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.004308s.
# 231218-22:29:44,20 nipype.workflow INFO:
# 	 [Job 504] Completed (fmriprep_22_1_wf.single_subject_08_wf.func_preproc_task_flanker_run_2_wf.func_derivatives_wf.ds_bold_surfs).
# 231218-22:29:45,868 nipype.workflow IMPORTANT:
# 	 fMRIPrep finished successfully!
# 231218-22:29:45,875 nipype.workflow IMPORTANT:
# 	 Works derived from this fMRIPrep execution should include the boilerplate text found in <OUTPUT_PATH>/logs/CITATION.md.

# %% [markdown]
# ## fMRIprep Results

# %% [markdown]
# The full result report is in content/sub-08.html and you can open this webpage in Jupyterlab or in the browser. Here a few items from the report as an example and for quickly checking:

# %% [markdown]
# ### T1 and brain mask
# Template T1-weighted image (if several T1w images were found), with contours delineating the detected brain mask and brain tissue segmentations.

# %%
from IPython.core.display import SVG
SVG(filename='content/sub-08/figures/sub-08_dseg.svg')

# %% [markdown]
# ### Surfaces
# Surfaces (white and pial) reconstructed with FreeSurfer (recon-all) overlaid on the participant's T1w template.

# %%
from IPython.core.display import SVG
SVG(filename='content/sub-08/figures/sub-08_desc-reconall_T1w.svg')

# %% [markdown]
# ### EPI-space to T1-space
# bbregister was used to generate transformations from EPI-space to T1w-space. Note that Nearest Neighbor interpolation is used in the reportlets in order to highlight potential spin-history and other artifacts, whereas final images are resampled using Lanczos interpolation.

# %%
from IPython.core.display import SVG
SVG(filename='content/sub-08/figures/sub-08_task-flanker_run-1_desc-bbregister_bold.svg')

# %% [markdown]
# ## Brain mask and (anatomical/temporal) CompCor ROIs
# Brain mask calculated on the BOLD signal (red contour), along with the regions of interest (ROIs) used for the estimation of physiological and movement confounding components that can be then used as nuisance regressors in analysis.
# The anatomical CompCor ROI (magenta contour) is a mask combining CSF and WM (white-matter), where voxels containing a minimal partial volume of GM have been removed.
# The temporal CompCor ROI (blue contour) contains the top 2% most variable voxels within the brain mask.
# The brain edge (or crown) ROI (green contour) picks signals outside but close to the brain, which are decomposed into 24 principal components.

# %%
from IPython.core.display import SVG
SVG(filename='content/sub-08/figures/sub-08_task-flanker_run-1_desc-rois_bold.svg')

# %% [markdown]
# ### Bold Summary
# Summary statistics are plotted, which may reveal trends or artifacts in the BOLD data. Global signals calculated within the whole-brain (GS), within the white-matter (WM) and within cerebro-spinal fluid (CSF) show the mean BOLD signal in their corresponding masks. DVARS and FD show the standardized DVARS and framewise-displacement measures for each time point.
# A carpet plot shows the time series for all voxels within the brain mask, or if --cifti-output was enabled, all grayordinates. Voxels are grouped into cortical (dark/light blue), and subcortical (orange) gray matter, cerebellum (green) and white matter and CSF (red), indicated by the color map on the left-hand side.

# %%
from IPython.core.display import SVG
SVG(filename='content/sub-08/figures/sub-08_task-flanker_run-1_desc-carpetplot_bold.svg')
